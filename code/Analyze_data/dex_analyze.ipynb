# %% [markdown]
# ## Volume of DEX

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('https://raw.githubusercontent.com/SciEcon/SRS2023_cex_dex/main/data/Processed_Data/dex_process.csv')
df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(12, 6))


plt.plot(df['Date'], df['USD_VOLUMES'], label='TOTAL_VOLUMES')


plt.title('Total Volumes over Time of DEX')
plt.xlabel('Date')
plt.ylabel('Amount')


plt.legend()
plt.show()

# %% [markdown]
# ## Fee of DEX

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('https://raw.githubusercontent.com/SciEcon/SRS2023_cex_dex/main/data/Processed_Data/dex_process.csv')
df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(12, 6))


plt.plot(df['Date'], df['FEES'], label='TOTAL_FEES')

plt.title('Total Fees over Time of DEX')
plt.xlabel('Date')
plt.ylabel('Amount')

plt.legend()
plt.show()

# %% [markdown]
# ## Volume and Fee of DEX

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('https://raw.githubusercontent.com/SciEcon/SRS2023_cex_dex/main/data/Processed_Data/dex_process.csv')
df['Date'] = pd.to_datetime(df['Date'])
plt.figure(figsize=(12, 6))

plt.semilogy(df['Date'], df['USD_VOLUMES'], label='TOTAL_VOLUMES')
plt.semilogy(df['Date'], df['FEES'], label='TOTAL_FEES')

plt.title('Total Volumes and Total Fees over Time of DEX')
plt.xlabel('Date')
plt.ylabel('Amount')

plt.legend()
plt.show()

# %% [markdown]
# ### correlation coefficient

# %%
import pandas as pd
from scipy.stats import pearsonr


df = pd.read_csv('https://raw.githubusercontent.com/SciEcon/SRS2023_cex_dex/main/data/Processed_Data/dex_process.csv')

usd_volumes = df['USD_VOLUMES']
fees = df['FEES']


correlation_coefficient, p_value = pearsonr(usd_volumes, fees)


print("correlation coefficient:", correlation_coefficient)
print("p-value:", p_value)
# Out:
# correlation coefficient: 0.6493713783618583
# p-value: 1.1334316423234452e-08

# %% [markdown]
# ### Granger causality

# %%
import pandas as pd
from statsmodels.tsa.stattools import grangercausalitytests

df = pd.read_csv('https://raw.githubusercontent.com/SciEcon/SRS2023_cex_dex/main/data/Processed_Data/dex_process.csv')


data = pd.DataFrame({
    'fees': df['FEES'],
    'volumes': df['USD_VOLUMES']
})

results = grangercausalitytests(data, maxlag=1, verbose=False)

granger_results = results[1][0]

p_value = granger_results['ssr_ftest'][1]


if p_value < 0.05:
    causality = "consistent Granger causality"
else:
    causality = "no consistent Granger causality"

print("p-value:", p_value)
print("Granger causality:", causality)
# Out:
# p-value: 0.9619541150571018
# Granger causality: no consistent Granger causality

# %% [markdown]
# ## Fee and Transaction of DEX

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('https://raw.githubusercontent.com/SciEcon/SRS2023_cex_dex/main/data/Processed_Data/dex_process.csv')
df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(12, 6))


plt.semilogy(df['Date'], df['FEES'], label='TOTAL_FEES')
plt.semilogy(df['Date'], df['TOTAL_TRANSACTIONS'], label='TOTAL_TRANSACTIONS')

plt.title('Total Fees and Total Transactions over Time of DEX')
plt.xlabel('Date')
plt.ylabel('Amount')

plt.legend()
plt.show()

# %% [markdown]
# ### correlation coefficient

# %%
import pandas as pd
from scipy.stats import pearsonr


df = pd.read_csv('https://raw.githubusercontent.com/SciEcon/SRS2023_cex_dex/main/data/Processed_Data/dex_process.csv')

total_transactions = df['TOTAL_TRANSACTIONS']
fees = df['FEES']


correlation_coefficient, p_value = pearsonr(total_transactions, fees)


print("correlation coefficient:", correlation_coefficient)
print("p-value:", p_value)
# Out:
# correlation coefficient: 0.7681019089332765
# p-value: 3.199093962367253e-13
